# %% [markdown]
# $\textbf{Lesson 3 Programming Assignment}$
# -

# %% [markdown]
# $\textbf{I. Graphs}$
#
# This is a graph because it consists of nodes (vertices) connected by edges (lines), representing relationships between the entities represented by the nodes.

# %%
import matplotlib.pyplot as pot
import networkx as nyx

mySeed = 69420

node_names = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
name_map = {i: name for i, name in enumerate(node_names)}

G = nyx.gnm_random_graph(len(node_names), 6, seed=mySeed)
G = nyx.relabel_nodes(G, name_map)
pos = nyx.spring_layout(G, seed=mySeed)

nyx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500)
pot.title("Example of a Graph")
pot.show()

# %% [markdown]
# $\textbf{II. Directed Graphs}$
#
# This is a directed graph (DiGraph) because the edges have a specific direction, indicating the flow or one-way relationship between the nodes, which distinguishes it from an undirected graph.

# %%
import matplotlib.pyplot as pot
import networkx as nyx

mySeed = 63

node_names = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
name_map = {i: name for i, name in enumerate(node_names)}

G = nyx.gnm_random_graph(len(node_names), 7, seed=mySeed, directed=True)
G = nyx.relabel_nodes(G, name_map)
pos = nyx.spring_layout(G, seed=mySeed)

nyx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500, arrowsize=20)
pot.title("Example of a Directed Graph (DiGraph)")
pot.show()

# %% [markdown]
# $\textbf{III. Simple Graphs}$
#
# This is a simple graph because it is a graph that does not have any loops or parallel edges.

# %%
import matplotlib.pyplot as pot
import networkx as nyx

mySeed = 420

node_names = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
name_map = {i: name for i, name in enumerate(node_names)}

G = nyx.gnm_random_graph(len(node_names), 8, seed=mySeed)
G = nyx.relabel_nodes(G, name_map)

nyx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500)
pot.title("Example of a Simple Graph")
pot.show()

# %% [markdown]
# $\textbf{IV. Complete Graphs}$
#
# This is a complete graph because every pair of distinct nodes in the graph is connected by a unique edge, resulting in a fully connected network where all nodes are directly linked to each other.

# %%
import matplotlib.pyplot as pot
import networkx as nyx

mySeed = 69420

node_names = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
name_map = {i: name for i, name in enumerate(node_names)}
G = nyx.complete_graph(len(node_names))
G = nyx.relabel_nodes(G, name_map)

pos = nx.spring_layout(G, seed=9875)
nyx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500)
pot.title("Example of a Complete Graph")
pot.show()

# %% [markdown]
# $\textbf{V. Bipartite Graphs}$
#
# This is a bipartite graph because its nodes can be divided into two disjoint sets such that every edge connects a node from one set to a node in the other set, without any edges connecting nodes within the same set.

# %%
import matplotlib.pyplot as pot
import networkx as nyx

mySeed = 86

node_names = ['A', 'B', 'C', 'D', 'E']
name_map = {i: name for i, name in enumerate(node_names)}
G = nyx.bipartite.gnmk_random_graph(2, 3, 6)
G = nyx.relabel_nodes(G, name_map)

# Separate nodes into two sets
set1 = {node for node, node_data in G.nodes(data=True) if node_data['bipartite'] == 0}
set2 = set(G) - set1

# Draw bipartite graph
pos = nyx.spring_layout(G, seed=mySeed)
nyx.draw(G, pos, nodelist=set1, node_color='skyblue', node_size=1500)
nyx.draw(G, pos, nodelist=set2, node_color='lightgreen', node_size=1500)
nyx.draw_networkx_labels(G, pos=pos)

pot.title("Example of a Bipartite Graph")
pot.show()

# %% [markdown]
# $\textbf{VI. Subgraphs}$
#
# This is a subgraph because it represents a subset of the original graph's nodes and edges, maintaining the connectivity and structure of the larger graph within a smaller portion of it.

# %%
import matplotlib.pyplot as pot
import networkx as nyx

mySeed = 69

node_names = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
name_map = {i: name for i, name in enumerate(node_names)}
G = nyx.gnm_random_graph(len(node_names), 8, seed=mySeed)
G = nyx.relabel_nodes(G, name_map)

pos = nx.spring_layout(G, seed=mySeed)
nyx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500)

subgraph_nodes = ['A', 'B', 'C', 'G', 'E']
subgraph = G.subgraph(subgraph_nodes)

nyx.draw(subgraph, pos=pos, with_labels=True, node_color='yellow', node_size=2000, edge_color='yellow')
pot.title('A Graph(Blue) and its Subgraph(Yellow)')
pot.show()

# %% [markdown]
# $\textbf{VII. Degree of a Vertex}$
#
# The degree of a vertex in a graph is the number of edges incident to that vertex, i.e., the number of edges connected to it.

# %%
import matplotlib.pyplot as pot
import networkx as nyx

mySeed = 69

node_names = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
name_map = {i: name for i, name in enumerate(node_names)}
G = nyx.gnm_random_graph(len(node_names), 8, seed=mySeed)
G = nyx.relabel_nodes(G, name_map)

pos = nx.spring_layout(G, seed=mySeed)
nyx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500)
pot.title("Sample graph for calculating the Degree of a Vertex")
pot.show()

# %% [markdown]
# <table>
#     <tr>
#         <th>Vertex</th>
#         <th>Degree</th>
#     </tr>
#     <tr>
#         <td>A</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>B</td>
#         <td>3</td>
#     </tr>
#     <tr>
#         <td>C</td>
#         <td>3</td>
#     </tr>
#     <tr>
#         <td>D</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>E</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>F</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>G</td>
#         <td>4</td>
#     </tr>
#     <tr>
#         <td>H</td>
#         <td>2</td>
#     </tr>
#     <tr>
#         <th>Total</th>
#         <td>16</td>
#     </tr>
# </table>

# %% [markdown]
# $\textbf{VIII. Handshake Theorem}$
#
# The Handshake Theorem states that in any finite undirected graph, the sum of the degrees of all vertices is twice the number of edges.
#
# Equation:
#
# The equation representing the Handshake Theorem is:
#
# $$\sum_{v} \text{deg}(v) = 2e$$
#
# Where:
# - $\text{deg}(v)$ represents the degree of a vertex.
# - $e$ represents the total number of edges.
#
# Example:
#
# Let's consider an example using the previous graph:
#
# Given:
# - Number of edges, $e = 5$
# - Total degrees, $t = 10$
#
# We can verify the Handshake Theorem:
#
# $$t = 2 \cdot e = 2 \cdot 5 = 10$$
#
# This confirms that the total sum of degrees in the graph is indeed twice the number of edges.

# %% [markdown]
# $\textbf{IX. Travelling in a Graph}$
#
# Travelling in a graph is accomplished by moving from one vertex to another along a sequence of adjaceny edges.
# Using the graph from below, we used different types of travelling in a graph to achieve it:

# %%
import matplotlib.pyplot as pot
import networkx as nyx

mySeed = 13

node_names = ['A', 'B', 'C', 'D', 'E', 'F']
name_map = {i: name for i, name in enumerate(node_names)}
G = nyx.gnm_random_graph(len(node_names), 7, seed=mySeed)
G = nyx.relabel_nodes(G, name_map)

# Draw the graph
pos = nx.spring_layout(G, seed=3)
nyx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500)
pot.text(-1, -0.9, "* Walk - From D to F: D->B->D->B->F\n"
         "* Trail - From D to F: D->B->F\n"
         "* Path - From D to E: D->B->A->E\n"
         "* Closed Walk - From B to B: B->A->E->A->C->D->B\n"
         "* Circuit - From A to A: A->E->F->B->A\n"
         "* Simple Circuit - From B to B: B->D->C->A->F->B")
pot.title("TRAVELLING IN A GRAPH")
pot.show()

# %% [markdown]
# $\textbf{X. Connectedness of a Graph}$
#
# This is a connected graph because there exists a path between every pair of nodes in the graph, meaning that every node is reachable from every other node through a series of edges.

# %%
import matplotlib.pyplot as pot
import networkx as nyx

mySeed = 95

node_names = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
name_map = {i: name for i, name in enumerate(node_names)}
G = nyx.gnm_random_graph(len(node_names), 8, seed=mySeed)
G = nyx.relabel_nodes(G, name_map)


pos = nx.spring_layout(G, seed=mySeed)
nyx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500)
pot.title("Example of a Connected Graph")
pot.show()

# %% [markdown]
# $\textbf{XI. Connected Components}$
#
# The red subgraph is a connected component because every node within it is connected to every other node, forming a self-contained connected structure within the larger graph.

# %%
import matplotlib.pyplot as plt
import networkx as nx

mySeed = 4545

node_names = ['A', 'B', 'C', 'D', 'E', 'F']
name_map = {i: name for i, name in enumerate(node_names)}
G = nx.gnm_random_graph(len(node_names), 7, seed=mySeed)
G = nx.relabel_nodes(G, name_map)

pos = nx.spring_layout(G, seed=mySeed)
nx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500)

subgraph_nodes = ['A', 'B', 'C', 'D']
subgraph = G.subgraph(subgraph_nodes)

nx.draw(subgraph, pos=pos, with_labels=True, node_color='yellow', node_size=2000, edge_color='yellow')
plt.title('H(Yellow) is a Connected Component of the Graph')
plt.show()

# %% [markdown]
# $\textbf{XII. Euler's Circuit}$
#
# This graph is an Euler's Circuit because it satisfies the following conditions:
#
# >if every vertex in the graph has an even degree.
#
# >The graph is connected

# %%
import matplotlib.pyplot as plt
import networkx as nx

node_names = ['A', 'B', 'C', 'D', 'E', 'F']
edge_list = [("A", "B"), ("B", "C"), ("C", "D"), ("D", "E"), ("E", "F"), ("F", "A"), ("A", "C"), ("C", "E"), ("A", "E")]
G = nx.Graph()
G.add_nodes_from(node_names)
G.add_edges_from(edge_list)

euler_c = list(nx.eulerian_circuit(G))
pos = nx.spring_layout(G, seed=35)

nx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=100)
for u, v in euler_c:
    x0, y0 = pos[u]
    x1, y1 = pos[v]
    dx = x1 - x0
    dy = y1 - y0
    mid_x = (x0 + x1) / 2
    mid_y = (y0 + y1) / 2
    arrow_length_factor = 0.2
    plt.arrow(mid_x, mid_y, dx * arrow_length_factor, dy * arrow_length_factor, head_width=0.02, head_length=0.06, fc='red', ec='red')

plt.title("Graph with Eulerian Circuit and Arrows")
plt.show()

# %% [markdown]
# $\textbf{XIII. Euler's Trail}$
#
# This graph is an Euler's Trail because it satisfies the following conditions:
#
# >The starting Node(C) and the ending Node(F) have odd degrees, while the rest have even degrees
#
# >The graph is connected

# %%
import matplotlib.pyplot as plt
import networkx as nx

node_names = ['A', 'B', 'C', 'D', 'E', 'F']
edge_list = [('A', 'B'), ('A', 'F'), ('C', 'B'), ('C', 'D'), ('C', 'F'), ('E', 'D'), ('E', 'F')]
G = nx.Graph()
G.add_nodes_from(node_names)
G.add_edges_from(edge_list)

euler_path = list(nx.eulerian_path(G))
pos = nx.planar_layout(G)

nx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=100)
for u, v in euler_path:
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        dx = x1 - x0
        dy = y1 - y0
        mid_x = (x0 + x1) / 2
        mid_y = (y0 + y1) / 2
        arrow_length_factor = 0.2
        plt.arrow(mid_x, mid_y, dx * arrow_length_factor, dy * arrow_length_factor, head_width=0.02, head_length=0.06, fc='red', ec='red')

plt.title("Graph with Eulerian Trail and Arrows")
plt.show()

# %% [markdown]
# $\textbf{XIV. Hamiltonian Circuits}$
#
# The graph is a Hamiltonian Circuit because it satisfies the following conditions:
#
# >The path contains every subgraph of the original graph
#
# >The path is connected
#
# >The path has the same number of edges as vertices
#
# >Every vertex of the path has degree 2

# %%
import matplotlib.pyplot as plt
import networkx as nx

def hamilton(G):
    F = [(G,[list(G.nodes())[0]])]
    n = G.number_of_nodes()
    while F:
        graph,path = F.pop()
        confs = []
        neighbors = (node for node in graph.neighbors(path[-1])
                     if node != path[-1]) #exclude self loops
        for neighbor in neighbors:
            conf_p = path[:]
            conf_p.append(neighbor)
            conf_g = nx.Graph(graph)
            conf_g.remove_node(path[-1])
            confs.append((conf_g,conf_p))
        for g,p in confs:
            if len(p)==n:
                return p
            else:
                F.append((g,p))
    return None

node_names = ['A', 'B', 'C', 'D']
edge_list = [("A", "B"), ("B", "C"), ("C", "D"), ("D", "A"), ("A", "C"), ("B", "D")]

G = nx.Graph()
G.add_nodes_from(node_names)
G.add_edges_from(edge_list)

# Find a Hamiltonian cycle

hamiltonian_c = list(hamilton(G))

# Visualize the graph
# Visualize the graph
pos = nx.spring_layout(G, seed=35)
nx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=100)

# Draw edges from Hamiltonian circuit
for i in range(len(hamiltonian_c) - 1):
    u, v = hamiltonian_c[i], hamiltonian_c[i + 1]
    nx.draw_networkx_edges(G, pos=pos, edgelist=[(u, v)], arrows=True, arrowsize=20, edge_color='red')

u, v = hamiltonian_c[-1], hamiltonian_c[0]
nx.draw_networkx_edges(G, pos=pos, edgelist=[(u, v)], arrows=True, arrowsize=20, edge_color='red')

plt.title("Graph with Hamiltonian Circuit")
plt.show()

# %% [markdown]
# $\textbf{XV. Travelling Salesman Problem}$

# %%
import matplotlib.pyplot as plt
import networkx as nx

node_names = ["A", "B", "C", "D"]
edges = [('A', 'B', {'weight': 30}),
         ('A', 'C', {'weight': 50}),
         ('A', 'D', {'weight': 40}),
         ('B', 'C', {'weight': 30}),
         ('B', 'D', {'weight': 35}),
         ('C', 'D', {'weight': 25})]

routes = [
    ['A', 'B', 'C', 'D', 'A'],
    ['A', 'B', 'D', 'C', 'A'],
    ['A', 'C', 'B', 'D', 'A'],
    ['A', 'C', 'D', 'B', 'A'],
    ['A', 'D', 'B', 'C', 'A']
]

fig, axs = plt.subplots(1, 5, figsize=(20, 4))

for i in range(5):
    G = nx.Graph()
    G.add_nodes_from(node_names)
    G.add_edges_from(edges)
    pos = nx.planar_layout(G)

    nx.draw_networkx_edge_labels(
        G, pos,
        edge_labels={('A', 'B'): '30',
                     ('A', 'C'): '50',
                     ('A', 'D'): '40',
                     ('B', 'C'): '30',
                     ('B', 'D'): '35',
                     ('C', 'D'): '25'},
        font_color='red', ax=axs[i]
    )

    nx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500, ax=axs[i])

    # Highlighting the specified route
    for j in range(len(routes[i]) - 1):
        nx.draw_networkx_edges(
            G, pos, edgelist=[(routes[i][j], routes[i][j + 1])],
            edge_color='red', width=2, ax=axs[i]
        )

    # Calculating the weight of the route
    weight = sum(G[routes[i][j]][routes[i][j + 1]]['weight'] for j in range(len(routes[i]) - 1))
    axs[i].set_title('Route {}'.format(i + 1))
    axs[i].text(0.5, -0.15, 'Weight: {}'.format(weight), horizontalalignment='center', verticalalignment='center',
                transform=axs[i].transAxes)

# Adjust layout
plt.tight_layout()
plt.gcf().canvas.manager.set_window_title("TRAVELLING SALESMAN PROBLEM")
plt.show()

# %% [markdown]
# As you can see from the five possible routes of the graph. The best possible and shortest path are:
#
# <table>
#     <tr>
#         <th>Route 2</th>
#         <td>A->B->D->C->A</td>
#     </tr>
#     <tr>
#         <th>Route 4</th>
#         <td>A->C->D->B->A</td>
#     </tr>
# </table>

# %% [markdown]
# $\textbf{XV. Travelling Salesman Problem - Example}$

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Define the nodes and edges
nodes = ['A', 'B', 'C', 'D', 'E']

edge_labels = {
    ('A', 'B'): 10,
    ('A', 'C'): 20,
    ('A', 'D'): 30,
    ('A', 'E'): 40,
    ('B', 'C'): 50,
    ('B', 'D'): 60,
    ('B', 'E'): 70,
    ('C', 'D'): 80,
    ('C', 'E'): 90,
    ('D', 'E'): 100,
    ('E', 'D'): 5
}

# Convert edge labels to the desired format
formatted_edge_labels = {edge: "{} feet".format(weight) for edge, weight in edge_labels.items()}

# Define Hamilton circuits
hamilton_circuits = [
    ['A', 'B', 'C', 'D', 'E', 'A'],
    ['A', 'B', 'D', 'E', 'C', 'A'],
    ['A', 'B', 'E', 'D', 'C', 'A'],
    ['A', 'E', 'D', 'C', 'B', 'A'],
    ['A', 'E', 'D', 'B', 'C', 'A']
]

# Plotting
fig, axs = plt.subplots(1, 5, figsize=(20, 4))

for i in range(5):
    G = nx.Graph()
    G.add_nodes_from(nodes)

    # Add edges with formatted labels
    for edge, label in formatted_edge_labels.items():
        G.add_edge(edge[0], edge[1], weight=edge_labels[edge])

    pos = nx.circular_layout(G)

    nx.draw_networkx_edge_labels(
        G, pos,
        edge_labels=formatted_edge_labels,
        font_color='red', ax=axs[i]
    )

    nx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500, ax=axs[i])

    # Highlighting the specified Hamilton circuit
    for j in range(len(hamilton_circuits[i]) - 1):
        nx.draw_networkx_edges(
            G, pos, edgelist=[(hamilton_circuits[i][j], hamilton_circuits[i][j + 1])],
            edge_color='red', width=2, ax=axs[i]
        )

    # Calculating and displaying the weight of the route
    weight = sum(G[hamilton_circuits[i][j]][hamilton_circuits[i][j + 1]]['weight'] for j in range(len(hamilton_circuits[i]) - 1))
    axs[i].set_title('Route {}'.format(i + 1))
    axs[i].text(0.5, -0.15, 'Weight: {}'.format(weight), horizontalalignment='center', verticalalignment='center',
                transform=axs[i].transAxes)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# As you can see from the five possible routes of the graph. The best possible and shortest path is:
#
# <table>
#     <tr>
#         <th>Route 5</th>
#         <td>A->E->D->B->C->A</td>
#     </tr>
# </table>
